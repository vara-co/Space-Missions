# %%
import pandas as pd 
import numpy as np
from unidecode import unidecode

# %%
file_path = "Resources/SpaceMission_cleanedLocFinal.csv"
encoding =  "ISO-8859-1"
space_missions_df = pd.read_csv(file_path, encoding=encoding)

# %%
space_missions_df.head()
# Out:
#      Company                                   Location        Date      Time  \
# 0  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-10-04  19:28:00
# 1  RVSN USSR  Site 1/5, Baikonur Cosmodrome, Kazakhstan  1957-11-03  02:30:00
# 2    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1957-12-06  16:44:00
# 3       AMBA   LC-26A, Cape Canaveral AFS, Florida, USA  1958-02-01  03:48:00
# 4    US Navy   LC-18A, Cape Canaveral AFS, Florida, USA  1958-02-05  07:33:00
#
#            Rocket         Mission RocketStatus MissionStatus Day/Night Launch
# 0  Sputnik 8K71PS       Sputnik-1      Retired       Success            Night
# 1  Sputnik 8K71PS       Sputnik-2      Retired       Success            Night
# 2        Vanguard    Vanguard TV3      Retired       Failure              Day
# 3          Juno I      Explorer 1      Retired       Success            Night
# 4        Vanguard  Vanguard TV3BU      Retired       Failure              Day

# %%
#Separate launches into two DataFrames
#This will be the US Space Missions and later on we will do the rest of the world's Space Missions
us_launches = space_missions_df[space_missions_df['Location'].str.contains('USA')]
#Display the US DataFrame
us_launches
# Out:
#       Company                                    Location        Date  \
# 2     US Navy    LC-18A, Cape Canaveral AFS, Florida, USA  1957-12-06
# 3        AMBA    LC-26A, Cape Canaveral AFS, Florida, USA  1958-02-01
# 4     US Navy    LC-18A, Cape Canaveral AFS, Florida, USA  1958-02-05
# 5        AMBA    LC-26A, Cape Canaveral AFS, Florida, USA  1958-03-05
# 6     US Navy    LC-18A, Cape Canaveral AFS, Florida, USA  1958-03-17
# ...       ...                                         ...         ...
# 4619    Astra    SLC-46, Cape Canaveral SFS, Florida, USA  2022-07-12
# 4622   SpaceX  LC-39A, Kennedy Space Center, Florida, USA  2022-07-15
# 4624   SpaceX    SLC-40, Cape Canaveral SFS, Florida, USA  2022-07-17
# 4625   SpaceX     SLC-4E, Vandenberg SFB, California, USA  2022-07-22
# 4627   SpaceX  LC-39A, Kennedy Space Center, Florida, USA  2022-07-24
#
#           Time            Rocket              Mission RocketStatus  \
# 2     16:44:00          Vanguard         Vanguard TV3      Retired
# 3     03:48:00            Juno I           Explorer 1      Retired
# 4     07:33:00          Vanguard       Vanguard TV3BU      Retired
# 5     18:27:00            Juno I           Explorer 2      Retired
# 6     12:15:00          Vanguard           Vanguard 1      Retired
# ...        ...               ...                  ...          ...
# 4619  17:43:00          Rocket 3     TROPICS Flight 1       Active
# 4622  00:44:00  Falcon 9 Block 5           CRS SpX-25       Active
# 4624  14:20:00  Falcon 9 Block 5  Starlink Group 4-22       Active
# 4625  17:39:00  Falcon 9 Block 5   Starlink Group 3-2       Active
# 4627  13:38:00  Falcon 9 Block 5  Starlink Group 4-25       Active
#
#      MissionStatus Day/Night Launch
# 2          Failure              Day
# 3          Success            Night
# 4          Failure              Day
# 5          Failure            Night
# 6          Success              Day
# ...            ...              ...
# 4619       Failure              Day
# 4622       Success            Night
# 4624       Success              Day
# 4625       Success              Day
# 4627       Success              Day
#
# [1472 rows x 9 columns]

# %%
#Split the "Location" column into separate parts
location_parts = us_launches['Location'].str.split(', ', expand=True)
#Rename the new columns dynamically based on the number of columns
new_columns = ['Complex ID', 'Launch Site', 'Territory', 'Country']
location_parts.columns = new_columns
#Concatenate the new columns with the original DataFrame
cleaned_US_df = pd.concat([us_launches, location_parts], axis=1)
#Drop the original "Location" column and the unnecessary column
cleaned_US_df = cleaned_US_df.drop(['Location'], axis=1, errors='ignore')
#Display the updated DataFrame
cleaned_US_df
# Out:
#       Company        Date      Time            Rocket              Mission  \
# 2     US Navy  1957-12-06  16:44:00          Vanguard         Vanguard TV3
# 3        AMBA  1958-02-01  03:48:00            Juno I           Explorer 1
# 4     US Navy  1958-02-05  07:33:00          Vanguard       Vanguard TV3BU
# 5        AMBA  1958-03-05  18:27:00            Juno I           Explorer 2
# 6     US Navy  1958-03-17  12:15:00          Vanguard           Vanguard 1
# ...       ...         ...       ...               ...                  ...
# 4619    Astra  2022-07-12  17:43:00          Rocket 3     TROPICS Flight 1
# 4622   SpaceX  2022-07-15  00:44:00  Falcon 9 Block 5           CRS SpX-25
# 4624   SpaceX  2022-07-17  14:20:00  Falcon 9 Block 5  Starlink Group 4-22
# 4625   SpaceX  2022-07-22  17:39:00  Falcon 9 Block 5   Starlink Group 3-2
# 4627   SpaceX  2022-07-24  13:38:00  Falcon 9 Block 5  Starlink Group 4-25
#
#      RocketStatus MissionStatus Day/Night Launch Complex ID  \
# 2         Retired       Failure              Day     LC-18A
# 3         Retired       Success            Night     LC-26A
# 4         Retired       Failure              Day     LC-18A
# 5         Retired       Failure            Night     LC-26A
# 6         Retired       Success              Day     LC-18A
# ...           ...           ...              ...        ...
# 4619       Active       Failure              Day     SLC-46
# 4622       Active       Success            Night     LC-39A
# 4624       Active       Success              Day     SLC-40
# 4625       Active       Success              Day     SLC-4E
# 4627       Active       Success              Day     LC-39A
#
#                Launch Site   Territory Country
# 2       Cape Canaveral AFS     Florida     USA
# 3       Cape Canaveral AFS     Florida     USA
# 4       Cape Canaveral AFS     Florida     USA
# 5       Cape Canaveral AFS     Florida     USA
# 6       Cape Canaveral AFS     Florida     USA
# ...                    ...         ...     ...
# 4619    Cape Canaveral SFS     Florida     USA
# 4622  Kennedy Space Center     Florida     USA
# 4624    Cape Canaveral SFS     Florida     USA
# 4625        Vandenberg SFB  California     USA
# 4627  Kennedy Space Center     Florida     USA
#
# [1472 rows x 12 columns]

# %%
rest_of_world_launches = space_missions_df[~(space_missions_df['Location'].str.contains('USA') )]
rest_of_world_launches
# Out:
#         Company                                           Location  \
# 0     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 1     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 8     RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 10    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 22    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# ...         ...                                                ...
# 4621        ESA  ELV-1, Guiana Space Centre - French Guiana, Fr...
# 4623       CASC       LC-9, Taiyuan Satellite Launch Center, China
# 4626       CASC    LC-101, Wenchang Satellite Launch Center, China
# 4628  CAS Space           , Jiuquan Satellite Launch Center, China
# 4629       CASC       LC-3, Xichang Satellite Launch Center, China
#
#             Date      Time          Rocket                  Mission  \
# 0     1957-10-04  19:28:00  Sputnik 8K71PS                Sputnik-1
# 1     1957-11-03  02:30:00  Sputnik 8K71PS                Sputnik-2
# 8     1958-04-27  09:01:00    Sputnik 8A91             Sputnik-3 #1
# 10    1958-05-15  07:12:00    Sputnik 8A91             Sputnik-3 #2
# 22    1958-09-23  07:40:00          Vostok       E-1 na A1 (Luna-1)
# ...          ...       ...             ...                      ...
# 4621  2022-07-13  13:13:00          Vega C       LARES 2 & Cubesats
# 4623  2022-07-15  22:57:00   Long March 2C  SuperView Neo 2-01 & 02
# 4626  2022-07-24  06:22:00   Long March 5B                  Wentian
# 4628  2022-07-27  04:12:00      Zhongke-1A              Demo Flight
# 4629  2022-07-29  13:28:00   Long March 2D       Yaogan 35 Group 03
#
#      RocketStatus MissionStatus Day/Night Launch
# 0         Retired       Success            Night
# 1         Retired       Success            Night
# 8         Retired       Failure              Day
# 10        Retired       Success              Day
# 22        Retired       Failure              Day
# ...           ...           ...              ...
# 4621       Active       Success              Day
# 4623       Active       Success            Night
# 4626       Active       Success              Day
# 4628       Active       Success            Night
# 4629       Active       Success              Day
#
# [3158 rows x 9 columns]

# %%
# Split the "Location" column into separate parts
new_worldcolumns = rest_of_world_launches['Location'].str.split(', ', expand=True)
# Rename the new columns dynamically based on the number of columns
new_world_columns = ['Complex ID', 'Launch Site', 'Country']
new_worldcolumns.columns = new_world_columns
# Concatenate the new columns with the original DataFrame for the rest of the world
cleaned_world_df = pd.concat([rest_of_world_launches, new_worldcolumns], axis=1)
# Drop the original "Location" column and the unnecessary columns
cleaned_world_df = cleaned_world_df.drop(['Location'], axis=1, errors='ignore')
# Display the updated DataFrame
cleaned_world_df
# Out:
#         Company        Date      Time          Rocket  \
# 0     RVSN USSR  1957-10-04  19:28:00  Sputnik 8K71PS
# 1     RVSN USSR  1957-11-03  02:30:00  Sputnik 8K71PS
# 8     RVSN USSR  1958-04-27  09:01:00    Sputnik 8A91
# 10    RVSN USSR  1958-05-15  07:12:00    Sputnik 8A91
# 22    RVSN USSR  1958-09-23  07:40:00          Vostok
# ...         ...         ...       ...             ...
# 4621        ESA  2022-07-13  13:13:00          Vega C
# 4623       CASC  2022-07-15  22:57:00   Long March 2C
# 4626       CASC  2022-07-24  06:22:00   Long March 5B
# 4628  CAS Space  2022-07-27  04:12:00      Zhongke-1A
# 4629       CASC  2022-07-29  13:28:00   Long March 2D
#
#                       Mission RocketStatus MissionStatus Day/Night Launch  \
# 0                   Sputnik-1      Retired       Success            Night
# 1                   Sputnik-2      Retired       Success            Night
# 8                Sputnik-3 #1      Retired       Failure              Day
# 10               Sputnik-3 #2      Retired       Success              Day
# 22         E-1 na A1 (Luna-1)      Retired       Failure              Day
# ...                       ...          ...           ...              ...
# 4621       LARES 2 & Cubesats       Active       Success              Day
# 4623  SuperView Neo 2-01 & 02       Active       Success            Night
# 4626                  Wentian       Active       Success              Day
# 4628              Demo Flight       Active       Success            Night
# 4629       Yaogan 35 Group 03       Active       Success              Day
#
#      Complex ID                          Launch Site     Country
# 0      Site 1/5                  Baikonur Cosmodrome  Kazakhstan
# 1      Site 1/5                  Baikonur Cosmodrome  Kazakhstan
# 8      Site 1/5                  Baikonur Cosmodrome  Kazakhstan
# 10     Site 1/5                  Baikonur Cosmodrome  Kazakhstan
# 22     Site 1/5                  Baikonur Cosmodrome  Kazakhstan
# ...         ...                                  ...         ...
# 4621      ELV-1  Guiana Space Centre - French Guiana      France
# 4623       LC-9      Taiyuan Satellite Launch Center       China
# 4626     LC-101     Wenchang Satellite Launch Center       China
# 4628                 Jiuquan Satellite Launch Center       China
# 4629       LC-3      Xichang Satellite Launch Center       China
#
# [3158 rows x 11 columns]

# %%
# Merging the DataFrames for cleaned_US_df and cleaned_world_df
# Columns in common to merge on
common_columns = ['Company', 'Date', 'Time', 'Rocket', 'Mission', 'RocketStatus', 'MissionStatus', 'Day/Night Launch', 'Complex ID', 'Launch Site', 'Country']

# Merge the dataframes based on the common columns
merged_df = cleaned_US_df.merge(cleaned_world_df, on=common_columns, how='outer')

# Show merged dataframe
merged_df
# Out:
#         Company        Date      Time         Rocket                  Mission  \
# 0       US Navy  1957-12-06  16:44:00       Vanguard             Vanguard TV3
# 1          AMBA  1958-02-01  03:48:00         Juno I               Explorer 1
# 2       US Navy  1958-02-05  07:33:00       Vanguard           Vanguard TV3BU
# 3          AMBA  1958-03-05  18:27:00         Juno I               Explorer 2
# 4       US Navy  1958-03-17  12:15:00       Vanguard               Vanguard 1
# ...         ...         ...       ...            ...                      ...
# 4625        ESA  2022-07-13  13:13:00         Vega C       LARES 2 & Cubesats
# 4626       CASC  2022-07-15  22:57:00  Long March 2C  SuperView Neo 2-01 & 02
# 4627       CASC  2022-07-24  06:22:00  Long March 5B                  Wentian
# 4628  CAS Space  2022-07-27  04:12:00     Zhongke-1A              Demo Flight
# 4629       CASC  2022-07-29  13:28:00  Long March 2D       Yaogan 35 Group 03
#
#      RocketStatus MissionStatus Day/Night Launch Complex ID  \
# 0         Retired       Failure              Day     LC-18A
# 1         Retired       Success            Night     LC-26A
# 2         Retired       Failure              Day     LC-18A
# 3         Retired       Failure            Night     LC-26A
# 4         Retired       Success              Day     LC-18A
# ...           ...           ...              ...        ...
# 4625       Active       Success              Day      ELV-1
# 4626       Active       Success            Night       LC-9
# 4627       Active       Success              Day     LC-101
# 4628       Active       Success            Night
# 4629       Active       Success              Day       LC-3
#
#                               Launch Site Territory Country
# 0                      Cape Canaveral AFS   Florida     USA
# 1                      Cape Canaveral AFS   Florida     USA
# 2                      Cape Canaveral AFS   Florida     USA
# 3                      Cape Canaveral AFS   Florida     USA
# 4                      Cape Canaveral AFS   Florida     USA
# ...                                   ...       ...     ...
# 4625  Guiana Space Centre - French Guiana       NaN  France
# 4626      Taiyuan Satellite Launch Center       NaN   China
# 4627     Wenchang Satellite Launch Center       NaN   China
# 4628      Jiuquan Satellite Launch Center       NaN   China
# 4629      Xichang Satellite Launch Center       NaN   China
#
# [4630 rows x 12 columns]

# %%
# Save the merged DataFrame into a CSV file to use in our question analysis
merged_df.to_csv('Resources/SpaceMission_Merged.csv', index=False)
